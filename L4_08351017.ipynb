# %% [markdown]
# # APPLICATIONS OF MACHINE LEARNING TO ECONOMICS AND FINANCE

# %% [markdown]
# ## Data Processing
#
# **Data Type** <br/>
# * 名稱型 (nominal)
# * 次序型 (ordinal)
# * 區間型 (interval)
# * 比例型 (ratio) <br/>
# ...
#
# 資料預處理的目的，就是在收集資料之後、開始進行分析之前，先行經過整理、清除，讓我們所使用的資料能有一定的可信度。這項工作是很重要的，因為資料分類與處理的品質，將會影響最後數據分析的結果。
#
# - data cleaning
#    noise, outlier, redundant data, missing values, ...
# - data integration
# - data transformation
# - dimensionality reduction

# %% [markdown]
# ## Plot
# 單一變數（一維變數）：
# - 類別型資料：柱狀圖（又稱長條圖）、圓餅圖
# - 連續型資料：直方圖、箱型圖。
#
# 二維變數：
# - 「類別型資料」對「類別型資料」：柱狀圖（又稱長條圖）
# - 「類別型資料」對「連續型資料」：直方圖或箱型圖
# - 「連續型資料」對「連續型資料」：散佈圖scatter plot

# %% [markdown]
# ## Python資料視覺化主要有三大套件：
# - Seaborn
# - Matplotlib
# - Plotly

# %% [markdown]
# ## Pandas Built-in Data Visualization

# %% [markdown]
# ### Plot Types
# * df.plot.area: 地區圖
# * df.plot.barh: 水平長條圖
# * df.plot.density: 機率密度圖???
# * df.plot.hist: 直方圖
# * df.plot.line: 折線圖
# * df.plot.scatter: 散佈圖
# * df.plot.bar: 垂直長條圖
# * df.plot.box: 箱形圖
# * df.plot.hexbin: 六邊箱圖
# * df.plot.kde: 核密度估計圖
# * df.plot.pie: 圓餅圖

# %%
import numpy as np
import pandas as pd

# %%
# Use this line to see plots in the notebook
# %matplotlib inline

# %% [markdown]
# **Fake data csv files**

# %%
df1 = pd.read_csv('C:\\Users\\user\\Desktop\\Python\\df1',index_col=0)
df2 = pd.read_csv('C:\\Users\\user\\Desktop\\Python\\df2')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# **Histogram** 直方圖

# %%
df1['A'].hist()

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# **Barplot**長條圖 <br/>
# DataFrame裡的列索引會在x軸，欄索引鍵會在y軸。

# %%
df2.plot.bar()

# %%
# alternative
df2.plot(kind='bar')

# %%
df2.plot.bar(stacked=True)

# %%
df2['a'].plot(kind='bar')

# %%
df2['a'].sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# #### 單叫a出來並漸減

# %%
df2['a'].plot(kind='barh')

# %% [markdown]
# **Pie Chart**圓餅圖 <br/>
# 當資料用圓餅圖呈現時，可以看出它占總體的百分比。

# %%
df2['b'].plot(kind='pie')

# %% [markdown]
# **BoxPlot**箱形圖 <br/>
# 中間箱子的兩端為第一四分位數（涵蓋25%之資料，Q1）與第三四分位數（涵蓋75%之資料，Q3），而箱子中間線為中位數（median）。<br/>
# 換言之，箱子涵蓋50%的資料。箱型外的圓圈，則是被判定成「異常值」。

# %%
df2.plot.box()

# %% [markdown]
# ##### 如果有outlier就會有個圈圈在外面

# %% [markdown]
# **Kernel Density Estimation plot (KDE)**

# %%
df2['a'].plot.kde()

# %% [markdown]
# ##### 機率密度圖，可看出說有沒有常態分配

# %% [markdown]
# **Line Plot**折線圖

# %%
df1.plot.line(y='B',figsize=(12,3))

# %% [markdown]
# ##### figsize是改圖的大小長寬

# %%
import seaborn as sns

# %% [markdown]
# **下載seaborn內建的資料集tips，這個資料集紀錄了餐廳客人給得小費以及相關的基本資料。**

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby(['smoker','sex']).size().unstack(1).plot(kind='bar')

# %% [markdown]
# ##### groupby區別兩個類別；unstack(1)是不要疊加起來

# %%
tips.groupby('sex')['total_bill'].plot(kind='hist', bins=30, alpha=0.5, legend=True) #alpha 是透明度的參數設定。
# Out:
# sex
# Male      AxesSubplot(0.125,0.125;0.775x0.755)
# Female    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: total_bill, dtype: object

# %% [markdown]
# ##### 不用alpha的透明度，兩個參數會重疊在一起，顏色會相同，無法區分出來

# %%
tips.boxplot(column='total_bill',by='sex')

# %% [markdown]
# ##### 單看圖中發現女生的花費比較低，比起男生來說

# %% [markdown]
# **Scatter Plot**散佈圖

# %%
df1.plot.scatter(x='A',y='B')

# %%
# color based off another column value
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ##### c決定圓圈大小

# %% [markdown]
# **Hexagonal Bin Plot**六邊箱圖(直譯)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %% [markdown]
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %% [markdown]
# ## Seaborn
# seaborn為python繪圖函式庫，以matplotlib為基礎封裝了許多實用的統計圖表，相較於matplotlib，seaborn的預設圖形更為好看，語法更為簡潔，並且良好的支援了pandas函式庫。 <br/>
#
# **優點：**
# 1. 畫圖指令非常簡單
# 2. 圖案好看 <br/>
#
# **缺點：**
# 1. 雖然99%的使用上都沒問題，但有些進階的圖案很難畫或是沒辦法畫（可用matplot互補）

# %% [markdown]
# ### Plot Types
# * factorplot 只要設定參數kind就可以以下各類圖表, 未將改名為catplot
# * boxplot
# * violinplot 小提琴圖
# * stripplot  分布散點圖
# * swarmplot  ???
# * barplot
# * countplot  計數直方圖
# * heatmap    熱區圖
# * distplot   ???
# * jointplot  ???
# * pairplot   散點圖矩陣
# * rugplot    地毯圖
# * kdeplot    核密度圖

# %%
sns.catplot(x='sex',y='total_bill',data=tips, kind="bar")

# %% [markdown]
# #### 類別型資料和連續型資料

# %% [markdown]
# **BarPlot**

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %% [markdown]
# **CountPlot**

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# Use matplotlib's **plt.figure(figsize=(width,height))** to change the size of most seaborn plots.

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0c30f552a55a> in <module>
# ----> 1 plt.figure(figsize=(12,3))
#       2 sns.countplot(x='sex',data=tips)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **BoxPlot**

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# ##### hue可再區分一個類別

# %% [markdown]
# **HeatMap**

# %%
# Matrix form for correlation data
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ##### 看資料關聯性

# %%
sns.heatmap(tips.corr())

# %% [markdown]
# ##### 用圖來看資料的關聯性

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# ##### 也可看出圖上有關連性數字

# %% [markdown]
# **distplot**

# %%
sns.distplot(tips['total_bill']) # Safe to ignore warnings

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %% [markdown]
# **jointplot**

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %% [markdown]
# ##### jointplot可看出各類型的圖形(正相關)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# **pairplot**

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# ##### 可區分性別和年齡等...

# %% [markdown]
# **lmplot**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %% [markdown]
# ## Matplotlib
# **優點：**
# 1. 相較於其他視覺化套件，matplot算是最歷史悠久，因此有很多的教學文章或是範例可參考
# 2. 畫圖功能最齊全，基本上沒什麼圖表畫不出來的 <br/>
#
# **缺點:**
# 1. 圖表不好看(新版的matplot其實也算好看，尤其在style功能出來之後可以自行切換圖表的風格)
# 2. 畫圖指令複雜
#
# official Matplotlib web page: http://matplotlib.org/ <br/>
#
#
# **Install with either:**
#
#    `conda install matplotlib`
#
# or
#
#    `pip install matplotlib`

# %%
import matplotlib.pyplot as plt

# %%
x=[5,4,3,2,1]
y=[1,2,3,4,5]
plt.plot(x,y,color='blue')
plt.show()

# %% [markdown]
# ##### 一定要.show() 圖才會出現

# %%
Image(filename = "img/para.png", width = 600, height = 800)

# %%
'''線條樣式'''
Image(filename = "img/lineForm.JPG", width = 225, height = 150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2b76f4d1649f> in <module>
#       1 '''線條樣式'''
# ----> 2 Image(filename = "img/lineForm.JPG", width = 225, height = 150)
#
# NameError: name 'Image' is not defined

# %% [markdown]
# **圖形色彩除了使用上表的字元當作參數值之外，也可以使用電腦系統的十六進制表示法，也就是一般RGB三原色模式的參數值。**

# %%
# alternative
plt.plot(x,y,color='#0000ff')
plt.show()

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'o',markersize=15)

# %%
plt.plot(x,y,color='g',linestyle='dashed',markeredgecolor='r',marker='+')

# %%
Image(filename = "img/axis1.jpg", width = 600, height = 800)

# %%
Image(filename = "img/axis2.jpg", width = 600, height = 800)

# %%
x=np.array([5,4,3,2,1])
y=pow(x,3)
plt.axis([1,6,1,150])
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### 有設定軸是從1,6和1,150

# %%
plt.plot(x,y,label='y = x ** 3')
plt.legend()

# %% [markdown]
# ##### legend()可以告訴你y=x^3，在左上角

# %%
'''圖例位置參數設定'''
Image(filename = "img/legend.JPG", width = 225, height = 150)

# %%
plt.plot(x,y,label='y = x ** 3')
plt.legend(loc=4,shadow=True)

# %% [markdown]
# ##### loc=4是換到右下角

# %%
z=pow(x,4)
w=pow(x,5)
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,w)
plt.title("The result")
plt.text(4.5,200,'x**3')
plt.text(4,400,'x**4')
plt.text(3.5,900,'x**5')
plt.show()

# %%
plt.subplots()
plt.axes()
plt.axes([0.65,0.65,0.2,0.2])

# %% [markdown]
# # Good Job!

# %% [markdown]
# # Exercise
# 使用TITANIC的資料繪圖

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **繪製age的直方圖, 區間值設為30**

# %%
df['age'].plot.hist(bins=30)

# %% [markdown]
# **製作survived和sex的交叉表**

# %%
df.groupby(['survived','sex']).size().unstack(1)
# Out:
# sex       female  male
# survived
# 0             81   468
# 1            233   109

# %% [markdown]
# **將結果製成圖**

# %%
df.groupby(['survived','sex']).size().unstack(1).plot(kind='bar')

# %% [markdown]
# **製作survived和age的圖。將依存活與否分成兩組，再將兩組的資料分別用直方圖來呈現。畫在同一格表格上**

# %%
df.groupby(['survived','age']).size().unstack(0).plot(kind='hist')

# %% [markdown]
# **用箱型圖來呈現**

# %%
sns.boxplot(x="survived", y="age", data=df,palette='rainbow')

# %% [markdown]
# **自由發揮, 至少再繪製3個不同的圖,並解釋其用意**

# %%
df.plot.scatter(x='who',y='fare')

# %% [markdown]
# ##### 圖中顯示小孩的票價的比例明顯低於男性和女性，且不論大人的票價最多就是到500

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ##### 想要上鐵達尼號的男女比例多寡，結果發現在當年男性上船的比例還是明顯高於女性

# %%
sns.lmplot(x='age',y='fare',data=df)

# %% [markdown]
# ##### 想看出說會不會年紀越高的人，買的票價會不會比較好，但明顯看出說60歲以前的人大多還是買低票價
